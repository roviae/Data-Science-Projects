# %%
import pandas as pd

# %%
wine_reviews = pd.read_csv("C:\\Users\Kiage Lydiah\\Documents\\DATA SCIENCE\\archive (1)\\winemag-data-130k-v2.csv", index_col=0)

# %%
wine_reviews.shape
# Out:
# (129971, 13)

# %%
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
fruit_sales = pd.DataFrame({'Apples':[35, 41], 'Bananas':[21, 34]}, index=['2017 Sales', '2018 Sales'])

# %%
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
courses_24 = pd.DataFrame({'Generals' : ['Environment','English','Bible'],
                            'CoreUnits' : ['PFinance', 'Planning', 'Econometrics']}, 
                          index=[0,1,3])

# %%
courses_24
# Out:
#       Generals     CoreUnits
# 0  Environment      PFinance
# 1      English      Planning
# 3        Bible  Econometrics

# %%
pd.set_option('display.max_rows', 5)

# %%
wine_reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews['country'][0]
# Out:
# 'Italy'

# %%
wine_reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
wine_reviews.country.iloc[0]
# Out:
# 'Italy'

# %%
wine_reviews.iloc[:, 0]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews.iloc[:, 1]
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
#                                 ...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
wine_reviews.iloc[:, 2]
# Out:
# 0                          Vulkà Bianco
# 1                              Avidagos
#                       ...
# 129969                              NaN
# 129970    Lieu-dit Harth Cuvée Caroline
# Name: designation, Length: 129971, dtype: object

# %%
wine_reviews.iloc[:3, 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
wine_reviews.iloc[:5, 1]
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# 3    Pineapple rind, lemon pith and orange blossom ...
# 4    Much like the regular bottling from 2012, this...
# Name: description, dtype: object

# %%
wine_reviews.iloc[:5, 3]
# Out:
# 0    87
# 1    87
# 2    87
# 3    87
# 4    87
# Name: points, dtype: int64

# %%
wine_reviews.iloc[:5, 2]
# Out:
# 0                          Vulkà Bianco
# 1                              Avidagos
# 2                                   NaN
# 3                  Reserve Late Harvest
# 4    Vintner's Reserve Wild Child Block
# Name: designation, dtype: object

# %%
wine_reviews.iloc[1:4, 1]
# Out:
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# 3    Pineapple rind, lemon pith and orange blossom ...
# Name: description, dtype: object

# %%
wine_reviews.iloc[1:5, 0]
# Out:
# 1    Portugal
# 2          US
# 3          US
# 4          US
# Name: country, dtype: object

# %%
wine_reviews.iloc[[23, 24, 25, 26], 0]
# Out:
# 23       US
# 24    Italy
# 25       US
# 26    Italy
# Name: country, dtype: object

# %%
new_data = wine_reviews.iloc[[23, 24, 25, 26], ]

# %%
new_data
# Out:
#    country                                        description  \
# 23      US  This wine from the Geneseo district offers aro...
# 24   Italy  Aromas of prune, blackcurrant, toast and oak c...
# 25      US  Oak and earth intermingle around robust aromas...
# 26   Italy  Pretty aromas of yellow flower and stone fruit...
#
#             designation  points  price           province         region_1  \
# 23  Signature Selection      87   22.0         California      Paso Robles
# 24                Aynat      87   35.0  Sicily & Sardinia          Sicilia
# 25  King Ridge Vineyard      87   69.0         California     Sonoma Coast
# 26               Dalila      87   13.0  Sicily & Sardinia  Terre Siciliane
#
#          region_2     taster_name taster_twitter_handle  \
# 23  Central Coast   Matt Kettmann         @mattkettmann
# 24            NaN   Kerin O’Keefe          @kerinokeefe
# 25         Sonoma  Virginie Boone               @vboone
# ...

# %%
wine_reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
wine_reviews.loc[: ,['points', 'taster_name', 'taster_twitter_handle']]
# Out:
#         points    taster_name taster_twitter_handle
# 0           87  Kerin O’Keefe          @kerinokeefe
# 1           87     Roger Voss            @vossroger
# ...        ...            ...                   ...
# 129969      90     Roger Voss            @vossroger
# 129970      90     Roger Voss            @vossroger
#
# [129971 rows x 3 columns]

# %%
wine_reviews.set_index('country')
# Out:
#                                                 description  \
# country
# Italy     Aromas include tropical fruit, broom, brimston...
# Portugal  This is ripe and fruity, a wine that is smooth...
# ...                                                     ...
# France    A dry style of Pinot Gris, this is crisp with ...
# France    Big, rich and off-dry, this is powered by inte...
#
#                             designation  points  price           province  \
# country
# Italy                      Vulkà Bianco      87    NaN  Sicily & Sardinia
# Portugal                       Avidagos      87   15.0              Douro
# ...                                 ...     ...    ...                ...
# France                              NaN      90   32.0             Alsace
# France    Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#          region_1 region_2    taster_name taster_twitter_handle  \
# country
# ...

# %%
wine_reviews.loc[wine_reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') & (wine_reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province region_1  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont   Barolo
# 130         Bricco Rocche Brunate      91   70.0           Piedmont   Barolo
# ...                           ...     ...    ...                ...      ...
# 129961                        NaN      90   30.0  Sicily & Sardinia  Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia  Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') | (wine_reviews.points >= 90)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
wine_reviews.loc[(wine_reviews.country.isin(['Italy', 'france']))]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
wine_reviews.loc[(wine_reviews.price.notnull())]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %%
wine_reviews.shape
# Out:
# (129971, 13)
